# %%
pip install netcdf4 xarray
# Out:
# Requirement already satisfied: netcdf4 in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (1.6.2)
# Requirement already satisfied: xarray in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (2023.6.0)
# Requirement already satisfied: numpy>=1.9 in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (from netcdf4) (1.23.5)
# Requirement already satisfied: cftime in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (from netcdf4) (1.6.2)
# Requirement already satisfied: pandas>=1.4 in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (from xarray) (2.2.3)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (from xarray) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (from pandas>=1.4->xarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (from pandas>=1.4->xarray) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (from pandas>=1.4->xarray) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/python3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->xarray) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# This script is to extract ducmass variable from the ncei dust nc4 file!
# created by : saima
# saves ducmass variable to a netcdf file from 2020-2024 May-August: total 615 days, time 12.30pm. 
# output: ducmass_combined_1230.nc

import xarray as xr
import numpy as np
import os

# Base path containing the dust data
base_path = "/Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data"
output_file = "ducmass_combined_1230.nc"

# Initialize a list to store filtered data
filtered_data = []

# Loop through years and files
for year in range(2020, 2025):
    year_path = os.path.join(base_path, str(year))
    print(f"Processing year: {year}")
    if not os.path.exists(year_path):
        print(f"Year folder not found: {year_path}")
        continue
    
    for file in os.listdir(year_path):
        # Skip hidden or metadata files
        if file.startswith("._") or not file.endswith(".nc4"):
            print(f"Skipping file: {file}")
            continue
        
        file_path = os.path.join(year_path, file)
        print(f"Processing file: {file_path}")
        
        try:
            # Open the dataset
            ds = xr.open_dataset(file_path, engine="netcdf4")
            
            # Check if DUCMASS exists
            if "DUCMASS" not in ds:
                print(f"'DUCMASS' variable not found in {file}")
                continue
            
            # Find the nearest time to 12:30 PM in each file
            target_time_str = "12:30:00"
            time_values = ds['time'].values
            target_time = time_values[0].astype('datetime64[D]') + np.timedelta64(12, 'h') + np.timedelta64(30, 'm')
            
            nearest_time = time_values[np.abs(time_values - target_time).argmin()]
            print(f"Nearest time found: {nearest_time}")
            
            # Extract DUCMASS data for the nearest time
            ducmass_1230 = ds['DUCMASS'].sel(time=nearest_time)
            filtered_data.append(ducmass_1230)
        
        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
            continue

# Combine and save the filtered data
if filtered_data:
    combined_ds = xr.concat(filtered_data, dim="time")
    combined_ds.to_netcdf(output_file)
    print(f"Filtered data saved to {output_file}")
else:
    print("No valid data found.")
# Out:
# Processing year: 2020
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200501.nc4
# Nearest time found: 2020-05-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200502.nc4
# Nearest time found: 2020-05-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200503.nc4
# Nearest time found: 2020-05-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200504.nc4
# Nearest time found: 2020-05-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200505.nc4
# Nearest time found: 2020-05-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200506.nc4
# Nearest time found: 2020-05-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200507.nc4
# Nearest time found: 2020-05-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200508.nc4
# Nearest time found: 2020-05-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200509.nc4
# Nearest time found: 2020-05-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200510.nc4
# Nearest time found: 2020-05-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200511.nc4
# Nearest time found: 2020-05-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200512.nc4
# Nearest time found: 2020-05-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200513.nc4
# Nearest time found: 2020-05-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200514.nc4
# Nearest time found: 2020-05-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200515.nc4
# Nearest time found: 2020-05-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200516.nc4
# Nearest time found: 2020-05-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200517.nc4
# Nearest time found: 2020-05-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200518.nc4
# Nearest time found: 2020-05-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200519.nc4
# Nearest time found: 2020-05-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200520.nc4
# Nearest time found: 2020-05-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200521.nc4
# Nearest time found: 2020-05-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200522.nc4
# Nearest time found: 2020-05-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200523.nc4
# Nearest time found: 2020-05-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200524.nc4
# Nearest time found: 2020-05-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200525.nc4
# Nearest time found: 2020-05-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200526.nc4
# Nearest time found: 2020-05-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200527.nc4
# Nearest time found: 2020-05-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200528.nc4
# Nearest time found: 2020-05-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200529.nc4
# Nearest time found: 2020-05-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200530.nc4
# Nearest time found: 2020-05-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200531.nc4
# Nearest time found: 2020-05-31T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200601.nc4
# Nearest time found: 2020-06-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200602.nc4
# Nearest time found: 2020-06-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200603.nc4
# Nearest time found: 2020-06-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200604.nc4
# Nearest time found: 2020-06-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200605.nc4
# Nearest time found: 2020-06-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200606.nc4
# Nearest time found: 2020-06-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200607.nc4
# Nearest time found: 2020-06-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200608.nc4
# Nearest time found: 2020-06-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200609.nc4
# Nearest time found: 2020-06-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200610.nc4
# Nearest time found: 2020-06-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200611.nc4
# Nearest time found: 2020-06-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200612.nc4
# Nearest time found: 2020-06-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200613.nc4
# Nearest time found: 2020-06-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200614.nc4
# Nearest time found: 2020-06-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200615.nc4
# Nearest time found: 2020-06-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200616.nc4
# Nearest time found: 2020-06-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200617.nc4
# Nearest time found: 2020-06-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200618.nc4
# Nearest time found: 2020-06-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200619.nc4
# Nearest time found: 2020-06-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200620.nc4
# Nearest time found: 2020-06-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200621.nc4
# Nearest time found: 2020-06-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200622.nc4
# Nearest time found: 2020-06-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200623.nc4
# Nearest time found: 2020-06-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200624.nc4
# Nearest time found: 2020-06-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200625.nc4
# Nearest time found: 2020-06-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200626.nc4
# Nearest time found: 2020-06-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200627.nc4
# Nearest time found: 2020-06-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200628.nc4
# Nearest time found: 2020-06-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200629.nc4
# Nearest time found: 2020-06-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200630.nc4
# Nearest time found: 2020-06-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200701.nc4
# Nearest time found: 2020-07-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200702.nc4
# Nearest time found: 2020-07-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200703.nc4
# Nearest time found: 2020-07-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200704.nc4
# Nearest time found: 2020-07-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200705.nc4
# Nearest time found: 2020-07-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200706.nc4
# Nearest time found: 2020-07-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200707.nc4
# Nearest time found: 2020-07-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200708.nc4
# Nearest time found: 2020-07-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200709.nc4
# Nearest time found: 2020-07-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200710.nc4
# Nearest time found: 2020-07-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200711.nc4
# Nearest time found: 2020-07-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200712.nc4
# Nearest time found: 2020-07-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200713.nc4
# Nearest time found: 2020-07-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200714.nc4
# Nearest time found: 2020-07-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200715.nc4
# Nearest time found: 2020-07-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200716.nc4
# Nearest time found: 2020-07-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200717.nc4
# Nearest time found: 2020-07-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200718.nc4
# Nearest time found: 2020-07-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200719.nc4
# Nearest time found: 2020-07-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200720.nc4
# Nearest time found: 2020-07-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200721.nc4
# Nearest time found: 2020-07-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200722.nc4
# Nearest time found: 2020-07-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200723.nc4
# Nearest time found: 2020-07-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200724.nc4
# Nearest time found: 2020-07-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200725.nc4
# Nearest time found: 2020-07-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200726.nc4
# Nearest time found: 2020-07-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200727.nc4
# Nearest time found: 2020-07-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200728.nc4
# Nearest time found: 2020-07-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200729.nc4
# Nearest time found: 2020-07-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200730.nc4
# Nearest time found: 2020-07-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200731.nc4
# Nearest time found: 2020-07-31T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200801.nc4
# Nearest time found: 2020-08-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200802.nc4
# Nearest time found: 2020-08-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200803.nc4
# Nearest time found: 2020-08-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200804.nc4
# Nearest time found: 2020-08-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200805.nc4
# Nearest time found: 2020-08-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200806.nc4
# Nearest time found: 2020-08-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200807.nc4
# Nearest time found: 2020-08-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200808.nc4
# Nearest time found: 2020-08-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200809.nc4
# Nearest time found: 2020-08-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200810.nc4
# Nearest time found: 2020-08-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200811.nc4
# Nearest time found: 2020-08-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200812.nc4
# Nearest time found: 2020-08-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200813.nc4
# Nearest time found: 2020-08-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200814.nc4
# Nearest time found: 2020-08-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200815.nc4
# Nearest time found: 2020-08-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200816.nc4
# Nearest time found: 2020-08-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200817.nc4
# Nearest time found: 2020-08-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200818.nc4
# Nearest time found: 2020-08-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200819.nc4
# Nearest time found: 2020-08-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200820.nc4
# Nearest time found: 2020-08-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200821.nc4
# Nearest time found: 2020-08-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200822.nc4
# Nearest time found: 2020-08-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200823.nc4
# Nearest time found: 2020-08-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200824.nc4
# Nearest time found: 2020-08-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200825.nc4
# Nearest time found: 2020-08-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200826.nc4
# Nearest time found: 2020-08-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200827.nc4
# Nearest time found: 2020-08-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200828.nc4
# Nearest time found: 2020-08-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200829.nc4
# Nearest time found: 2020-08-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200830.nc4
# Nearest time found: 2020-08-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2020/MERRA2_400.tavg1_2d_aer_Nx.20200831.nc4
# Nearest time found: 2020-08-31T12:30:00.000000000
# Skipping file: ._MERRA2_400.tavg1_2d_aer_Nx.20200510.nc4
# Skipping file: ._MERRA2_400.tavg1_2d_aer_Nx.20200702.nc4
# Processing year: 2021
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210501.nc4
# Nearest time found: 2021-05-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210502.nc4
# Nearest time found: 2021-05-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210503.nc4
# Nearest time found: 2021-05-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210504.nc4
# Nearest time found: 2021-05-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210505.nc4
# Nearest time found: 2021-05-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210506.nc4
# Nearest time found: 2021-05-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210507.nc4
# Nearest time found: 2021-05-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210508.nc4
# Nearest time found: 2021-05-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210509.nc4
# Nearest time found: 2021-05-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210510.nc4
# Nearest time found: 2021-05-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210511.nc4
# Nearest time found: 2021-05-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210512.nc4
# Nearest time found: 2021-05-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210513.nc4
# Nearest time found: 2021-05-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210514.nc4
# Nearest time found: 2021-05-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210515.nc4
# Nearest time found: 2021-05-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210516.nc4
# Nearest time found: 2021-05-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210517.nc4
# Nearest time found: 2021-05-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210518.nc4
# Nearest time found: 2021-05-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210519.nc4
# Nearest time found: 2021-05-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210520.nc4
# Nearest time found: 2021-05-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210521.nc4
# Nearest time found: 2021-05-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210522.nc4
# Nearest time found: 2021-05-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210523.nc4
# Nearest time found: 2021-05-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210524.nc4
# Nearest time found: 2021-05-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210525.nc4
# Nearest time found: 2021-05-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210526.nc4
# Nearest time found: 2021-05-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210527.nc4
# Nearest time found: 2021-05-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210528.nc4
# Nearest time found: 2021-05-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210529.nc4
# Nearest time found: 2021-05-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210530.nc4
# Nearest time found: 2021-05-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_400.tavg1_2d_aer_Nx.20210531.nc4
# Nearest time found: 2021-05-31T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210601.nc4
# Nearest time found: 2021-06-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210602.nc4
# Nearest time found: 2021-06-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210603.nc4
# Nearest time found: 2021-06-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210604.nc4
# Nearest time found: 2021-06-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210605.nc4
# Nearest time found: 2021-06-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210606.nc4
# Nearest time found: 2021-06-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210607.nc4
# Nearest time found: 2021-06-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210608.nc4
# Nearest time found: 2021-06-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210609.nc4
# Nearest time found: 2021-06-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210610.nc4
# Nearest time found: 2021-06-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210611.nc4
# Nearest time found: 2021-06-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210612.nc4
# Nearest time found: 2021-06-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210613.nc4
# Nearest time found: 2021-06-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210614.nc4
# Nearest time found: 2021-06-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210615.nc4
# Nearest time found: 2021-06-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210616.nc4
# Nearest time found: 2021-06-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210617.nc4
# Nearest time found: 2021-06-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210618.nc4
# Nearest time found: 2021-06-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210619.nc4
# Nearest time found: 2021-06-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210620.nc4
# Nearest time found: 2021-06-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210621.nc4
# Nearest time found: 2021-06-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210622.nc4
# Nearest time found: 2021-06-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210623.nc4
# Nearest time found: 2021-06-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210624.nc4
# Nearest time found: 2021-06-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210625.nc4
# Nearest time found: 2021-06-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210626.nc4
# Nearest time found: 2021-06-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210627.nc4
# Nearest time found: 2021-06-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210628.nc4
# Nearest time found: 2021-06-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210629.nc4
# Nearest time found: 2021-06-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210630.nc4
# Nearest time found: 2021-06-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210701.nc4
# Nearest time found: 2021-07-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210702.nc4
# Nearest time found: 2021-07-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210703.nc4
# Nearest time found: 2021-07-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210704.nc4
# Nearest time found: 2021-07-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210705.nc4
# Nearest time found: 2021-07-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210706.nc4
# Nearest time found: 2021-07-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210707.nc4
# Nearest time found: 2021-07-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210708.nc4
# Nearest time found: 2021-07-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210709.nc4
# Nearest time found: 2021-07-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210710.nc4
# Nearest time found: 2021-07-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210711.nc4
# Nearest time found: 2021-07-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210712.nc4
# Nearest time found: 2021-07-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210713.nc4
# Nearest time found: 2021-07-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210714.nc4
# Nearest time found: 2021-07-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210715.nc4
# Nearest time found: 2021-07-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210716.nc4
# Nearest time found: 2021-07-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210717.nc4
# Nearest time found: 2021-07-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210718.nc4
# Nearest time found: 2021-07-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210719.nc4
# Nearest time found: 2021-07-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210720.nc4
# Nearest time found: 2021-07-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210721.nc4
# Nearest time found: 2021-07-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210722.nc4
# Nearest time found: 2021-07-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210723.nc4
# Nearest time found: 2021-07-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210724.nc4
# Nearest time found: 2021-07-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210725.nc4
# Nearest time found: 2021-07-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210726.nc4
# Nearest time found: 2021-07-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210727.nc4
# Nearest time found: 2021-07-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210728.nc4
# Nearest time found: 2021-07-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210729.nc4
# Nearest time found: 2021-07-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210730.nc4
# Nearest time found: 2021-07-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210731.nc4
# Nearest time found: 2021-07-31T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210801.nc4
# Nearest time found: 2021-08-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210802.nc4
# Nearest time found: 2021-08-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210803.nc4
# Nearest time found: 2021-08-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210804.nc4
# Nearest time found: 2021-08-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210805.nc4
# Nearest time found: 2021-08-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210806.nc4
# Nearest time found: 2021-08-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210807.nc4
# Nearest time found: 2021-08-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210808.nc4
# Nearest time found: 2021-08-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210809.nc4
# Nearest time found: 2021-08-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210810.nc4
# Nearest time found: 2021-08-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210811.nc4
# Nearest time found: 2021-08-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210812.nc4
# Nearest time found: 2021-08-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210813.nc4
# Nearest time found: 2021-08-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210814.nc4
# Nearest time found: 2021-08-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210815.nc4
# Nearest time found: 2021-08-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210816.nc4
# Nearest time found: 2021-08-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210817.nc4
# Nearest time found: 2021-08-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210818.nc4
# Nearest time found: 2021-08-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210819.nc4
# Nearest time found: 2021-08-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210820.nc4
# Nearest time found: 2021-08-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210821.nc4
# Nearest time found: 2021-08-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210822.nc4
# Nearest time found: 2021-08-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210823.nc4
# Nearest time found: 2021-08-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210824.nc4
# Nearest time found: 2021-08-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210825.nc4
# Nearest time found: 2021-08-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210826.nc4
# Nearest time found: 2021-08-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210827.nc4
# Nearest time found: 2021-08-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210828.nc4
# Nearest time found: 2021-08-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210829.nc4
# Nearest time found: 2021-08-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210830.nc4
# Nearest time found: 2021-08-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2021/MERRA2_401.tavg1_2d_aer_Nx.20210831.nc4
# Nearest time found: 2021-08-31T12:30:00.000000000
# Processing year: 2022
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220501.nc4
# Nearest time found: 2022-05-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220502.nc4
# Nearest time found: 2022-05-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220503.nc4
# Nearest time found: 2022-05-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220504.nc4
# Nearest time found: 2022-05-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220505.nc4
# Nearest time found: 2022-05-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220506.nc4
# Nearest time found: 2022-05-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220507.nc4
# Nearest time found: 2022-05-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220508.nc4
# Nearest time found: 2022-05-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220509.nc4
# Nearest time found: 2022-05-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220510.nc4
# Nearest time found: 2022-05-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220511.nc4
# Nearest time found: 2022-05-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220512.nc4
# Nearest time found: 2022-05-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220513.nc4
# Nearest time found: 2022-05-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220514.nc4
# Nearest time found: 2022-05-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220515.nc4
# Nearest time found: 2022-05-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220516.nc4
# Nearest time found: 2022-05-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220517.nc4
# Nearest time found: 2022-05-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220518.nc4
# Nearest time found: 2022-05-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220519.nc4
# Nearest time found: 2022-05-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220520.nc4
# Nearest time found: 2022-05-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220521.nc4
# Nearest time found: 2022-05-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220522.nc4
# Nearest time found: 2022-05-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220523.nc4
# Nearest time found: 2022-05-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220524.nc4
# Nearest time found: 2022-05-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220525.nc4
# Nearest time found: 2022-05-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220526.nc4
# Nearest time found: 2022-05-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220527.nc4
# Nearest time found: 2022-05-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220528.nc4
# Nearest time found: 2022-05-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220529.nc4
# Nearest time found: 2022-05-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220530.nc4
# Nearest time found: 2022-05-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220531.nc4
# Nearest time found: 2022-05-31T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2022/MERRA2_400.tavg1_2d_aer_Nx.20220601.nc4
# Nearest time found: 2022-06-01T12:30:00.000000000
# ...
# Nearest time found: 2024-05-31T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240601.nc4
# Nearest time found: 2024-06-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240602.nc4
# Nearest time found: 2024-06-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240603.nc4
# Nearest time found: 2024-06-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240604.nc4
# Nearest time found: 2024-06-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240605.nc4
# Nearest time found: 2024-06-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240606.nc4
# Nearest time found: 2024-06-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240607.nc4
# Nearest time found: 2024-06-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240608.nc4
# Nearest time found: 2024-06-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240609.nc4
# Nearest time found: 2024-06-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240610.nc4
# Nearest time found: 2024-06-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240611.nc4
# Nearest time found: 2024-06-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240612.nc4
# Nearest time found: 2024-06-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240613.nc4
# Nearest time found: 2024-06-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240614.nc4
# Nearest time found: 2024-06-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240615.nc4
# Nearest time found: 2024-06-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240616.nc4
# Nearest time found: 2024-06-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240617.nc4
# Nearest time found: 2024-06-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240618.nc4
# Nearest time found: 2024-06-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240619.nc4
# Nearest time found: 2024-06-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240620.nc4
# Nearest time found: 2024-06-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240621.nc4
# Nearest time found: 2024-06-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240622.nc4
# Nearest time found: 2024-06-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240623.nc4
# Nearest time found: 2024-06-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240624.nc4
# Nearest time found: 2024-06-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240625.nc4
# Nearest time found: 2024-06-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240626.nc4
# Nearest time found: 2024-06-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240627.nc4
# Nearest time found: 2024-06-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240628.nc4
# Nearest time found: 2024-06-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240629.nc4
# Nearest time found: 2024-06-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240630.nc4
# Nearest time found: 2024-06-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240701.nc4
# Nearest time found: 2024-07-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240702.nc4
# Nearest time found: 2024-07-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240703.nc4
# Nearest time found: 2024-07-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240704.nc4
# Nearest time found: 2024-07-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240705.nc4
# Nearest time found: 2024-07-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240706.nc4
# Nearest time found: 2024-07-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240707.nc4
# Nearest time found: 2024-07-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240708.nc4
# Nearest time found: 2024-07-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240709.nc4
# Nearest time found: 2024-07-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240710.nc4
# Nearest time found: 2024-07-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240711.nc4
# Nearest time found: 2024-07-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240712.nc4
# Nearest time found: 2024-07-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240713.nc4
# Nearest time found: 2024-07-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240714.nc4
# Nearest time found: 2024-07-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240715.nc4
# Nearest time found: 2024-07-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240716.nc4
# Nearest time found: 2024-07-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240717.nc4
# Nearest time found: 2024-07-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240718.nc4
# Nearest time found: 2024-07-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240719.nc4
# Nearest time found: 2024-07-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240720.nc4
# Nearest time found: 2024-07-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240721.nc4
# Nearest time found: 2024-07-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240722.nc4
# Nearest time found: 2024-07-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240723.nc4
# Nearest time found: 2024-07-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240724.nc4
# Nearest time found: 2024-07-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240725.nc4
# Nearest time found: 2024-07-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240726.nc4
# Nearest time found: 2024-07-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240727.nc4
# Nearest time found: 2024-07-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240728.nc4
# Nearest time found: 2024-07-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240729.nc4
# Nearest time found: 2024-07-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240730.nc4
# Nearest time found: 2024-07-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240731.nc4
# Nearest time found: 2024-07-31T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240801.nc4
# Nearest time found: 2024-08-01T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240802.nc4
# Nearest time found: 2024-08-02T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240803.nc4
# Nearest time found: 2024-08-03T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240804.nc4
# Nearest time found: 2024-08-04T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240805.nc4
# Nearest time found: 2024-08-05T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240806.nc4
# Nearest time found: 2024-08-06T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240807.nc4
# Nearest time found: 2024-08-07T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240808.nc4
# Nearest time found: 2024-08-08T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240809.nc4
# Nearest time found: 2024-08-09T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240810.nc4
# Nearest time found: 2024-08-10T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240811.nc4
# Nearest time found: 2024-08-11T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240812.nc4
# Nearest time found: 2024-08-12T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240813.nc4
# Nearest time found: 2024-08-13T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240814.nc4
# Nearest time found: 2024-08-14T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240815.nc4
# Nearest time found: 2024-08-15T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240816.nc4
# Nearest time found: 2024-08-16T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240817.nc4
# Nearest time found: 2024-08-17T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240818.nc4
# Nearest time found: 2024-08-18T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240819.nc4
# Nearest time found: 2024-08-19T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240820.nc4
# Nearest time found: 2024-08-20T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240821.nc4
# Nearest time found: 2024-08-21T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240822.nc4
# Nearest time found: 2024-08-22T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240823.nc4
# Nearest time found: 2024-08-23T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240824.nc4
# Nearest time found: 2024-08-24T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240825.nc4
# Nearest time found: 2024-08-25T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240826.nc4
# Nearest time found: 2024-08-26T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240827.nc4
# Nearest time found: 2024-08-27T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240828.nc4
# Nearest time found: 2024-08-28T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240829.nc4
# Nearest time found: 2024-08-29T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240830.nc4
# Nearest time found: 2024-08-30T12:30:00.000000000
# Processing file: /Volumes/Work/Thesis/Paul_miller/Thesis_Work/Dust/dust_data/2024/MERRA2_400.tavg1_2d_aer_Nx.20240831.nc4
# Nearest time found: 2024-08-31T12:30:00.000000000
# Filtered data saved to ducmass_combined_1230.nc

# %%
# This script is to CSV of ducmass variable nc file!
# created by : saima
# converts nc to csv from 2020-2024 May-August: total 615 days, time 12.30pm. 
# output : ducmass.csv

import xarray as xr
import pandas as pd

def netcdf_to_csv(nc_file, output_csv):
    """
    Convert a NetCDF file to a CSV, keeping only non-NaN values.

    Parameters:
    nc_file (str): Path to the NetCDF file.
    output_csv (str): Path to save the CSV file.
    """
    # Open the NetCDF file
    ds = xr.open_dataset(nc_file)
    
    # Check if DUCMASS exists
    if 'DUCMASS' not in ds.variables:
        print("DUCMASS variable not found in the dataset.")
        return
    
    # Convert to a DataFrame
    df = ds[['DUCMASS']].to_dataframe().reset_index()
    
    # Remove NaN values
    df_cleaned = df.dropna(subset=['DUCMASS'])
    
    # Save to CSV
    df_cleaned.to_csv(output_csv, index=False)
    print(f"CSV saved to {output_csv}")

# File paths
netcdf_file = "ducmass_combined_1230.nc"  # Replace with your NetCDF file
output_csv_file = "ducmass.csv"  # Desired CSV file name

# Convert NetCDF to CSV
netcdf_to_csv(netcdf_file, output_csv_file)
# Out:
# CSV saved to ducmass.csv

# %%
# This script is to align ducmass lat and lon according to sst grid!
# created by : saima
# converts, time (615), 12.30pm, lat (140), lon (400), dust 
# output : ducmass_on_sst_grid.nc

import xarray as xr
import numpy as np

# Load the SST and DUCMASS datasets
print("Loading datasets...")
sst_ds = xr.open_dataset("./dust_dataset/new_cropped_oisst.nc")   # Replace with actual SST file path
dust_ds = xr.open_dataset("./dust_dataset/ducmass_cropped.nc")  # Replace with actual DUCMASS file path

# Define new latitude and longitude grids from SST
new_lat = sst_ds['lat']
new_lon = sst_ds['lon']

# Convert longitudes in dust dataset from [-180,180] to [0,360] if necessary
if dust_ds['lon'].min() < 0:
    print("Converting longitudes in DUCMASS dataset from [-180,180] to [0,360]...")
    dust_ds = dust_ds.assign_coords(lon=(dust_ds['lon'] + 360) % 360)
    dust_ds = dust_ds.sortby('lon')

# Interpolate DUCMASS to SST grid
print("Interpolating DUCMASS to SST resolution...")
ducmass_interp = dust_ds.interp(lat=new_lat, lon=new_lon, method="linear")

# Keep only DUCMASS, lat, lon, and time
ducmass_interp = ducmass_interp[['DUCMASS']]

# Convert time to daily format (remove hours)
ducmass_interp['time'] = ducmass_interp['time'].dt.floor("D")  # Keep only date (YYYY-MM-DD)

# Save the new NetCDF file
output_nc = "ducmass_on_sst_grid.nc"
print(f"Saving interpolated DUCMASS dataset to {output_nc}...")
ducmass_interp.to_netcdf(output_nc, mode='w', format='NETCDF4')

print("Processing complete! DUCMASS data is now aligned with SST grid.")
# Out:
# Loading datasets...
# Interpolating DUCMASS to SST resolution...
# Saving interpolated DUCMASS dataset to ducmass_on_sst_grid.nc...
# Processing complete! DUCMASS data is now aligned with SST grid.

# %%
# Converts new_cropped_oisst.nc and ducmass_on_sst_grid.nc file to CSV
# time, lat, lon, sst, time, lat, lon, ducmass


import xarray as xr
import pandas as pd

def save_sst_dust_to_csv(sst_file, dust_file, output_csv):
    print("Loading SST dataset...")
    sst_ds = xr.open_dataset(sst_file)

    # Check if 'zlev' exists in SST and drop it
    if 'zlev' in sst_ds.dims:
        print("Dropping 'zlev' dimension from SST dataset...")
        sst_ds = sst_ds.isel(zlev=0)  # Select the first level if it exists

    print("Loading Dust dataset...")
    dust_ds = xr.open_dataset(dust_file)

    # Extract SST variables (time, lat, lon, sst)
    print("Extracting SST variables...")
    sst_df = sst_ds[['sst']].to_dataframe().reset_index()

    # Extract DUCMASS variable
    print("Extracting DUCMASS variable...")
    dust_df = dust_ds[['DUCMASS']].to_dataframe().reset_index()

    # Print dataset shapes for debugging
    print(f"SST dataset shape: {sst_df.shape}")
    print(f"Dust dataset shape: {dust_df.shape}")

    # Concatenate without merging
    print("Concatenating datasets without merging...")
    combined_df = pd.concat([sst_df, dust_df], axis=1)

    # Save to CSV
    print(f"Saving concatenated dataset to {output_csv}...")
    combined_df.to_csv(output_csv, index=False)
    print(f"✅ Dataset successfully saved to {output_csv}")

# File paths
sst_file = "./dust_dataset/new_cropped_oisst.nc"   # Replace with actual SST NetCDF file path
dust_file = "./dust_dataset/ducmass_on_sst_grid.nc" # Replace with actual Dust NetCDF file path
output_csv = "./dust_dataset/sst_dust_combined.csv"

# Run the function
save_sst_dust_to_csv(sst_file, dust_file, output_csv)
# Out:
# Loading SST dataset...
# Dropping 'zlev' dimension from SST dataset...
# Loading Dust dataset...
# Extracting SST variables...
# Extracting DUCMASS variable...
# SST dataset shape: (34440000, 5)
# Dust dataset shape: (34440000, 4)
# Concatenating datasets without merging...
# Saving concatenated dataset to ./dust_dataset/sst_dust_combined.csv...
# ✅ Dataset successfully saved to ./dust_dataset/sst_dust_combined.csv

# %%
# Converts CSV to CSV
# sst_dust_combined.csv to sst_dust_cleaned.csv
# dropped time, lat, lon, sst, time, lat, lon, ducmass to time, lat, lon, sst, ducmass

import pandas as pd

# Load the dataset
input_csv = "./dust_dataset/sst_dust_combined.csv"  # Update with your actual filename
output_csv = "./dust_dataset/sst_dust_cleaned.csv"

print("Loading dataset...")
df = pd.read_csv(input_csv)

# Identify column names (modify if needed)
columns_to_drop = ['zlev', 'time.1', 'lat.1', 'lon.1']  # Ensure these match your actual column names

# Check actual column names
print("Original Columns:", df.columns)

# Drop unnecessary columns
df = df.drop(columns=[col for col in columns_to_drop if col in df.columns], errors='ignore')

# Replace missing values with NaN
df = df.fillna('NaN')

# Save the cleaned CSV
print(f"Saving cleaned dataset to {output_csv}...")
df.to_csv(output_csv, index=False)

print("Dataset cleaned and saved successfully!")
# Out:
# Loading dataset...
# Original Columns: Index(['time', 'lat', 'lon', 'sst', 'zlev', 'time.1', 'lat.1', 'lon.1',
#        'DUCMASS'],
#       dtype='object')
# Saving cleaned dataset to ./dust_dataset/sst_dust_cleaned.csv...
# Dataset cleaned and saved successfully!

# %%
# CSV to CSV
# sst_dust_cleaned.csv TO sst_dust_filtered.csv
# drops all rows with sst NaN values

import pandas as pd

# Load the cleaned dataset
input_csv = "./dust_dataset/sst_dust_cleaned.csv"
output_csv = "./dust_dataset/sst_dust_filtered.csv"

print("Loading dataset...")
df = pd.read_csv(input_csv)

# Check initial shape
print(f"Original dataset shape: {df.shape}")

# Drop rows where 'sst' is NaN
df_filtered = df.dropna(subset=['sst'])

# Check shape after removing NaN rows
print(f"Filtered dataset shape: {df_filtered.shape}")

# Save the filtered dataset
df_filtered.to_csv(output_csv, index=False)
print(f"Filtered dataset saved to {output_csv}")
# Out:
# Loading dataset...
# Original dataset shape: (34440000, 5)
# Filtered dataset shape: (25705770, 5)
# Filtered dataset saved to ./dust_dataset/sst_dust_filtered.csv

# %%
# CSV to CSV
# sst_dust_filtered.csv TO sst_dust_final.csv
# add missing values of ducmass with NaN values. converts scientific notation to digital numbers

## DIDNOT UPDATE NAN VALUES IN DUCMASS..... ALSO THERE ARE SOME SCIENTIFIC NOTATION STILL THERE..


import pandas as pd

# Define input and output file paths
input_csv = "./dust_dataset/sst_dust_filtered.csv"  # Change this if your file is in a different location
output_csv = "./dust_dataset/sst_dust_final.csv"

# Load dataset
print("Loading dataset...")
df = pd.read_csv(input_csv)

# Convert DUCMASS missing values to NaN
print("Replacing missing DUCMASS values with NaN...")
df["DUCMASS"] = df["DUCMASS"].replace([1e15, -1e15], pd.NA)  # Replace invalid scientific notation values

# Convert DUCMASS to normal decimal format
print("Converting DUCMASS scientific notation to normal values...")
df["DUCMASS"] = df["DUCMASS"].astype(float)

# Save cleaned dataset
print(f"Saving cleaned dataset to {output_csv}...")
df.to_csv(output_csv, index=False)

print("Processing complete.")
# Out:
# Loading dataset...
# Replacing missing DUCMASS values with NaN...
# Converting DUCMASS scientific notation to normal values...
# Saving cleaned dataset to ./dust_dataset/sst_dust_final.csv...
# Processing complete.

# %%
# CSV to CSV
# february 6, 2025
# sst_dust_filtered.csv TO sst_dust_final2.csv
# add missing values of ducmass with NaN values. converts scientific notation to digital numbers

# This one worked well handling missing values with NaN and converted all scientific values but still some E numbers. 


import pandas as pd

# Define file paths
input_csv = "./dust_dataset/sst_dust_final2.csv"  # Modify if needed
output_csv = "./dust_dataset/sst_dust_final3.csv"

# Load dataset
print("Loading dataset...")
df = pd.read_csv(input_csv)

# Replace DUCMASS missing values with 0
print("Replacing missing DUCMASS values with 0...")
df["DUCMASS"] = df["DUCMASS"].replace([1e15, -1e15], 0)  # Replace extreme values
df["DUCMASS"] = df["DUCMASS"].fillna(0)  # Replace NaN with 0

# Convert DUCMASS from scientific notation to normal values
print("Converting DUCMASS from scientific notation to normal values...")
df["DUCMASS"] = df["DUCMASS"].apply(lambda x: f"{x:.10f}")

# Save cleaned dataset
print(f"Saving cleaned dataset to {output_csv}...")
df.to_csv(output_csv, index=False)

print("Processing complete. DUCMASS values converted and missing values filled with 0.")
# Out:
# Loading dataset...
# Replacing missing DUCMASS values with 0...
# Converting DUCMASS from scientific notation to normal values...
# Saving cleaned dataset to ./dust_dataset/sst_dust_final3.csv...
# Processing complete. DUCMASS values converted and missing values filled with 0.

# %%
# create train, validation, and test datasets while ensuring missing 
# DUCMASS values are replaced with NaN and prints the last 10 rows

# OUTPUT: train_dataset, test_dataset, validation_dataset

import pandas as pd

# Define the file path
csv_file = "./dust_dataset/sst_dust_final3.csv"

# Load the dataset
print("Loading dataset...")
df = pd.read_csv(csv_file)

# Convert 'time' column to datetime format
df['time'] = pd.to_datetime(df['time'], errors='coerce')

# Ensure missing DUCMASS values are explicitly filled with NaN
df['DUCMASS'] = df['DUCMASS'].replace({None: pd.NA, "": pd.NA}).astype(float)

# Function to split and save dataset
def save_dataset(df, start_year, end_year, filename):
    subset_df = df[(df['time'].dt.year >= start_year) & (df['time'].dt.year <= end_year)].copy()
    subset_df['DUCMASS'] = subset_df['DUCMASS'].fillna(pd.NA)  # Fill missing DUCMASS with NaN
    subset_df.to_csv(filename, index=False)
    print(f"\n{filename} saved successfully!")
    print(f"Total rows: {subset_df.shape[0]}")
    print(f"Last 10 rows of {filename}:")
    print(subset_df.tail(10))

# Create and save Train dataset (2020-2022)
train_file = "./dust_dataset/train_dataset.csv"
save_dataset(df, 2020, 2022, train_file)

# Create and save Validation dataset (2023)
validation_file = "./dust_dataset/validation_dataset.csv"
save_dataset(df, 2023, 2023, validation_file)

# Create and save Test dataset (2024)
test_file = "./dust_dataset/test_dataset.csv"
save_dataset(df, 2024, 2024, test_file)
# Out:
# Loading dataset...
#
# ./dust_dataset/train_dataset.csv saved successfully!
# Total rows: 15423462
# Last 10 rows of ./dust_dataset/train_dataset.csv:
#                         time     lat      lon        sst   DUCMASS
# 15423452 2022-08-31 12:00:00  34.875  351.375  23.090000  0.000307
# 15423453 2022-08-31 12:00:00  34.875  351.625  23.500000  0.000310
# 15423454 2022-08-31 12:00:00  34.875  351.875  23.760000  0.000312
# 15423455 2022-08-31 12:00:00  34.875  352.125  23.779999  0.000303
# 15423456 2022-08-31 12:00:00  34.875  352.375  23.630000  0.000293
# 15423457 2022-08-31 12:00:00  34.875  352.625  23.460000  0.000285
# 15423458 2022-08-31 12:00:00  34.875  352.875  23.269999  0.000279
# 15423459 2022-08-31 12:00:00  34.875  353.125  22.840000  0.000272
# 15423460 2022-08-31 12:00:00  34.875  353.375  22.119999  0.000262
# 15423461 2022-08-31 12:00:00  34.875  353.625  21.510000  0.000252
#
# ./dust_dataset/validation_dataset.csv saved successfully!
# Total rows: 5141154
# Last 10 rows of ./dust_dataset/validation_dataset.csv:
#                         time     lat      lon        sst   DUCMASS
# 20564606 2023-08-31 12:00:00  34.875  351.375  23.769999  0.000004
# 20564607 2023-08-31 12:00:00  34.875  351.625  23.840000  0.000003
# 20564608 2023-08-31 12:00:00  34.875  351.875  23.930000  0.000002
# 20564609 2023-08-31 12:00:00  34.875  352.125  24.010000  0.000001
# 20564610 2023-08-31 12:00:00  34.875  352.375  24.050000  0.000001
# 20564611 2023-08-31 12:00:00  34.875  352.625  23.990000  0.000001
# 20564612 2023-08-31 12:00:00  34.875  352.875  23.720000  0.000002
# 20564613 2023-08-31 12:00:00  34.875  353.125  23.180000  0.000002
# 20564614 2023-08-31 12:00:00  34.875  353.375  22.460000  0.000005
# 20564615 2023-08-31 12:00:00  34.875  353.625  21.680000  0.000007
#
# ./dust_dataset/test_dataset.csv saved successfully!
# Total rows: 5141154
# Last 10 rows of ./dust_dataset/test_dataset.csv:
#                         time     lat      lon        sst   DUCMASS
# 25705760 2024-08-31 12:00:00  34.875  351.375  22.810000  0.000104
# 25705761 2024-08-31 12:00:00  34.875  351.625  22.810000  0.000122
# 25705762 2024-08-31 12:00:00  34.875  351.875  23.019999  0.000139
# 25705763 2024-08-31 12:00:00  34.875  352.125  23.490000  0.000152
# 25705764 2024-08-31 12:00:00  34.875  352.375  24.039999  0.000166
# 25705765 2024-08-31 12:00:00  34.875  352.625  24.369999  0.000185
# 25705766 2024-08-31 12:00:00  34.875  352.875  24.189999  0.000210
# 25705767 2024-08-31 12:00:00  34.875  353.125  23.570000  0.000235
# 25705768 2024-08-31 12:00:00  34.875  353.375  22.890000  0.000235
# 25705769 2024-08-31 12:00:00  34.875  353.625  22.380000  0.000236

# %%
# checks sst_dust_combined lat and lon values if they match in both the dataset or not
# Load merged dataset
import pandas as pd
import pandas as pd

# Load the merged dataset
merged_file = './dust_dataset/sst_dust_combined.csv'
print("Loading merged dataset...")
df = pd.read_csv(merged_file)

# Display the first few rows of 'lat' and 'lon' from SST and Dust
print("\nFirst 5 rows of 'lat' from SST:")
print(df[['lat']].head())

print("\nFirst 5 rows of 'lat.1' from Dust:")
print(df[['lat.1']].head())

print("\nFirst 5 rows of 'lon' from SST:")
print(df[['lon']].head())

print("\nFirst 5 rows of 'lon.1' from Dust:")
print(df[['lon.1']].head())

# Check for mismatches between 'lat' columns
mismatched_lat = df[df['lat'] != df['lat.1']]
print(f"\nNumber of mismatched latitude rows: {mismatched_lat.shape[0]}")

# Check for mismatches between 'lon' columns
mismatched_lon = df[df['lon'] != df['lon.1']]
print(f"Number of mismatched longitude rows: {mismatched_lon.shape[0]}")

# Display some mismatched latitude rows if any
if not mismatched_lat.empty:
    print("\nFirst 5 mismatched latitude rows:")
    print(mismatched_lat[['lat', 'lat.1']].head())
else:
    print("\nAll latitude entries match between SST and Dust datasets.")

# Display some mismatched longitude rows if any
if not mismatched_lon.empty:
    print("\nFirst 5 mismatched longitude rows:")
    print(mismatched_lon[['lon', 'lon.1']].head())
else:
    print("\nAll longitude entries match between SST and Dust datasets.")

# Optionally, save mismatched lat/lon rows to CSV if needed
# mismatched_lat.to_csv('./dust_dataset/mismatched_lat.csv', index=False)
# mismatched_lon.to_csv('./dust_dataset/mismatched_lon.csv', index=False)
# Out:
# Loading merged dataset...
#
# First 5 rows of 'lat' from SST:
#      lat
# 0  0.125
# 1  0.125
# 2  0.125
# 3  0.125
# 4  0.125
#
# First 5 rows of 'lat.1' from Dust:
#    lat.1
# 0  0.125
# 1  0.125
# 2  0.125
# 3  0.125
# 4  0.125
#
# First 5 rows of 'lon' from SST:
#        lon
# 0  260.125
# 1  260.375
# 2  260.625
# 3  260.875
# 4  261.125
#
# First 5 rows of 'lon.1' from Dust:
#      lon.1
# 0  260.125
# 1  260.375
# 2  260.625
# 3  260.875
# 4  261.125
#
# Number of mismatched latitude rows: 0
# Number of mismatched longitude rows: 0
#
# All latitude entries match between SST and Dust datasets.
#
# All longitude entries match between SST and Dust datasets.

# %%
# THIS IS THE FINAL SCRIPT THAT RUNS AND MAKES 3 DATASETS OF TRAIN , TEST AND VALIDATION
# FEBRUARY 6, 2025
# FOR SST+ DUST
import pandas as pd

# Load the final dataset
final_csv = "./dust_dataset/sst_dust_final3.csv"
print("Loading final dataset...")
df = pd.read_csv(final_csv)

# Convert 'time' column to datetime format
df['time'] = pd.to_datetime(df['time'], errors='coerce')

# Function to split and save dataset
def save_dataset(df, start_year, end_year, filename):
    # Filter dataset for the specified year range
    subset_df = df[(df['time'].dt.year >= start_year) & (df['time'].dt.year <= end_year)].copy()
    
    # Save the dataset to CSV
    subset_df.to_csv(filename, index=False)
    
    # Display summary
    print(f"\n{filename} saved successfully!")
    print(f"Total rows: {subset_df.shape[0]}")
    print(f"Last 10 rows of {filename}:")
    print(subset_df.tail(10))

# Create and save Train dataset (2020-2022)
train_file = "./dust_dataset/Dust_data/train_dataset.csv"
save_dataset(df, 2020, 2022, train_file)

# Create and save Validation dataset (2023)
validation_file = "./dust_dataset/Dust_data/validation_dataset.csv"
save_dataset(df, 2023, 2023, validation_file)

# Create and save Test dataset (2024)
test_file = "./dust_dataset/Dust_data/test_dataset.csv"
save_dataset(df, 2024, 2024, test_file)

print("\nAll datasets created successfully!")
# Out:
# Loading final dataset...
#
# ./dust_dataset/Dust_data/train_dataset.csv saved successfully!
# Total rows: 15423462
# Last 10 rows of ./dust_dataset/Dust_data/train_dataset.csv:
#                         time     lat      lon        sst   DUCMASS
# 15423452 2022-08-31 12:00:00  34.875  351.375  23.090000  0.000307
# 15423453 2022-08-31 12:00:00  34.875  351.625  23.500000  0.000310
# 15423454 2022-08-31 12:00:00  34.875  351.875  23.760000  0.000312
# 15423455 2022-08-31 12:00:00  34.875  352.125  23.779999  0.000303
# 15423456 2022-08-31 12:00:00  34.875  352.375  23.630000  0.000293
# 15423457 2022-08-31 12:00:00  34.875  352.625  23.460000  0.000285
# 15423458 2022-08-31 12:00:00  34.875  352.875  23.269999  0.000279
# 15423459 2022-08-31 12:00:00  34.875  353.125  22.840000  0.000272
# 15423460 2022-08-31 12:00:00  34.875  353.375  22.119999  0.000262
# 15423461 2022-08-31 12:00:00  34.875  353.625  21.510000  0.000252
#
# ./dust_dataset/Dust_data/validation_dataset.csv saved successfully!
# Total rows: 5141154
# Last 10 rows of ./dust_dataset/Dust_data/validation_dataset.csv:
#                         time     lat      lon        sst   DUCMASS
# 20564606 2023-08-31 12:00:00  34.875  351.375  23.769999  0.000004
# 20564607 2023-08-31 12:00:00  34.875  351.625  23.840000  0.000003
# 20564608 2023-08-31 12:00:00  34.875  351.875  23.930000  0.000002
# 20564609 2023-08-31 12:00:00  34.875  352.125  24.010000  0.000001
# 20564610 2023-08-31 12:00:00  34.875  352.375  24.050000  0.000001
# 20564611 2023-08-31 12:00:00  34.875  352.625  23.990000  0.000001
# 20564612 2023-08-31 12:00:00  34.875  352.875  23.720000  0.000002
# 20564613 2023-08-31 12:00:00  34.875  353.125  23.180000  0.000002
# 20564614 2023-08-31 12:00:00  34.875  353.375  22.460000  0.000005
# 20564615 2023-08-31 12:00:00  34.875  353.625  21.680000  0.000007
#
# ./dust_dataset/Dust_data/test_dataset.csv saved successfully!
# Total rows: 5141154
# Last 10 rows of ./dust_dataset/Dust_data/test_dataset.csv:
#                         time     lat      lon        sst   DUCMASS
# 25705760 2024-08-31 12:00:00  34.875  351.375  22.810000  0.000104
# 25705761 2024-08-31 12:00:00  34.875  351.625  22.810000  0.000122
# 25705762 2024-08-31 12:00:00  34.875  351.875  23.019999  0.000139
# 25705763 2024-08-31 12:00:00  34.875  352.125  23.490000  0.000152
# 25705764 2024-08-31 12:00:00  34.875  352.375  24.039999  0.000166
# 25705765 2024-08-31 12:00:00  34.875  352.625  24.369999  0.000185
# 25705766 2024-08-31 12:00:00  34.875  352.875  24.189999  0.000210
# 25705767 2024-08-31 12:00:00  34.875  353.125  23.570000  0.000235
# 25705768 2024-08-31 12:00:00  34.875  353.375  22.890000  0.000235
# 25705769 2024-08-31 12:00:00  34.875  353.625  22.380000  0.000236
#
# All datasets created successfully!

# %%
# THIS IS THE FINAL SCRIPT THAT RUNS AND MAKES 3 DATASETS OF TRAIN , TEST AND VALIDATION
# FEBRUARY 6, 2025
# FOR SST
import pandas as pd

# Load the final dataset
final_csv = "./sst_dataset.csv"
print("Loading final dataset...")
df = pd.read_csv(final_csv)

# Convert 'time' column to datetime format
df['time'] = pd.to_datetime(df['time'], errors='coerce')

# Function to split and save dataset
def save_dataset(df, start_year, end_year, filename):
    # Filter dataset for the specified year range
    subset_df = df[(df['time'].dt.year >= start_year) & (df['time'].dt.year <= end_year)].copy()
    
    # Save the dataset to CSV
    subset_df.to_csv(filename, index=False)
    
    # Display summary
    print(f"\n{filename} saved successfully!")
    print(f"Total rows: {subset_df.shape[0]}")
    print(f"Last 10 rows of {filename}:")
    print(subset_df.tail(10))

# Create and save Train dataset (2020-2022)
train_file = "./dataset/train_dataset.csv"
save_dataset(df, 2020, 2022, train_file)

# Create and save Validation dataset (2023)
validation_file = "./dataset/validation_dataset.csv"
save_dataset(df, 2023, 2023, validation_file)

# Create and save Test dataset (2024)
test_file = "./dataset/test_dataset.csv"
save_dataset(df, 2024, 2024, test_file)

print("\nAll datasets created successfully!")
# Out:
# Loading final dataset...
#
# ./dataset/train_dataset.csv saved successfully!
# Total rows: 15423462
# Last 10 rows of ./dataset/train_dataset.csv:
#                         time     lat      lon        sst
# 15423452 2022-08-31 12:00:00  34.875  351.375  23.090000
# 15423453 2022-08-31 12:00:00  34.875  351.625  23.500000
# 15423454 2022-08-31 12:00:00  34.875  351.875  23.760000
# 15423455 2022-08-31 12:00:00  34.875  352.125  23.779999
# 15423456 2022-08-31 12:00:00  34.875  352.375  23.630000
# 15423457 2022-08-31 12:00:00  34.875  352.625  23.460000
# 15423458 2022-08-31 12:00:00  34.875  352.875  23.269999
# 15423459 2022-08-31 12:00:00  34.875  353.125  22.840000
# 15423460 2022-08-31 12:00:00  34.875  353.375  22.119999
# 15423461 2022-08-31 12:00:00  34.875  353.625  21.510000
#
# ./dataset/validation_dataset.csv saved successfully!
# Total rows: 5141154
# Last 10 rows of ./dataset/validation_dataset.csv:
#                         time     lat      lon        sst
# 20564606 2023-08-31 12:00:00  34.875  351.375  23.769999
# 20564607 2023-08-31 12:00:00  34.875  351.625  23.840000
# 20564608 2023-08-31 12:00:00  34.875  351.875  23.930000
# 20564609 2023-08-31 12:00:00  34.875  352.125  24.010000
# 20564610 2023-08-31 12:00:00  34.875  352.375  24.050000
# 20564611 2023-08-31 12:00:00  34.875  352.625  23.990000
# 20564612 2023-08-31 12:00:00  34.875  352.875  23.720000
# 20564613 2023-08-31 12:00:00  34.875  353.125  23.180000
# 20564614 2023-08-31 12:00:00  34.875  353.375  22.460000
# 20564615 2023-08-31 12:00:00  34.875  353.625  21.680000
#
# ./dataset/test_dataset.csv saved successfully!
# Total rows: 5141154
# Last 10 rows of ./dataset/test_dataset.csv:
#                         time     lat      lon        sst
# 25705760 2024-08-31 12:00:00  34.875  351.375  22.810000
# 25705761 2024-08-31 12:00:00  34.875  351.625  22.810000
# 25705762 2024-08-31 12:00:00  34.875  351.875  23.019999
# 25705763 2024-08-31 12:00:00  34.875  352.125  23.490000
# 25705764 2024-08-31 12:00:00  34.875  352.375  24.039999
# 25705765 2024-08-31 12:00:00  34.875  352.625  24.369999
# 25705766 2024-08-31 12:00:00  34.875  352.875  24.189999
# 25705767 2024-08-31 12:00:00  34.875  353.125  23.570000
# 25705768 2024-08-31 12:00:00  34.875  353.375  22.890000
# 25705769 2024-08-31 12:00:00  34.875  353.625  22.380000
#
# All datasets created successfully!
